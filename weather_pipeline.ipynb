# %%
# !pip install google-cloud
# !pip install google
# !pip install matplotlib
# Out:
# Requirement already satisfied: google-cloud in ./my_project_env/lib/python3.10/site-packages (0.34.0)
# Requirement already satisfied: google in ./my_project_env/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in ./my_project_env/lib/python3.10/site-packages (from google) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in ./my_project_env/lib/python3.10/site-packages (from beautifulsoup4->google) (2.5)
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 2.2 MB/s eta 0:00:003.0 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Collecting numpy>=1.21 (from matplotlib)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in ./my_project_env/lib/python3.10/site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./my_project_env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./my_project_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 15.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 11.7 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 21.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 21.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 22.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.8.4 numpy-1.26.4 pillow-10.3.0 pyparsing-3.1.2

# %%
# https://dev.to/wachuka_james/building-a-weather-data-pipeline-with-pyspark-prefect-and-google-cloud-19k8

from pyspark.sql import SparkSession
# from google.cloud import storage
# from google.cloud import bigquery

import requests
import json
# from google.cloud.exceptions import NotFound
import random

import matplotlib.pyplot as plt

# %%
# OpenWeatherMap API and base url
api_key = ""
base_url = "https://api.openweathermap.org/data/2.5/weather"

# city = ['San Antonio']
cities = ['San Antonio', 'Austin', 'Dallas', 'Houston']

spark = SparkSession.builder.appName("WeatherData").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://COUNCIL:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>WeatherData</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
def fetch_weather_data(city):
    # Fetch request from OpenWeatherMap API for city weather
    params = {"q": city, "appid": api_key, "units": "metric"}
    response = requests.get(base_url, params=params)
    data = response.json()
        
    # Extract the weather data from the API response
    # use https://m.openweathermap.org/current to find which data to add
    temp = data["main"]["temp"]
    humidity = data["main"]["humidity"]
    wind_speed = data["wind"]["speed"]
    # longitude
    # latitute
    # rain = data["rain"]["rain"]

    # TODO: add precipations
    
    df = spark.createDataFrame([(city, temp, humidity, wind_speed)],
                               ["City", "Temperature", "Humidity", "WindSpeed"])
    return df

# %%
# fetch_weather_data function to fetch weather data
weather_data = None
for city in cities:
    city_weather_data = fetch_weather_data(city)
    if weather_data is None:
        weather_data = city_weather_data
    else:
        weather_data = weather_data.union(city_weather_data)

# Basic processing and transformation on the weather
weather_data = weather_data.filter("temperature > 10") \
                           .groupBy("City") \
                           .agg({"Temperature": "avg", "Humidity": "avg", "WindSpeed": "max"}) \
                           .withColumnRenamed("avg(Temperature)", "Average Temperature") \
                           .withColumnRenamed("avg(Humidity)", "Average Humidity") \
                           .withColumnRenamed("max(WindSpeed)", "Max WindSpeed")
                           # .withColumnRenamed("avg(Rain)", "Average Rain") \

weather_data.show()
# Out:
# +-----------+-------------------+----------------+-------------+
# |       City|Average Temperature|Average Humidity|Max WindSpeed|
# +-----------+-------------------+----------------+-------------+
# |San Antonio|              26.64|            75.0|         9.26|
# |     Austin|              26.21|            79.0|         8.23|
# |     Dallas|              25.25|            79.0|         6.69|
# |    Houston|              25.36|            79.0|         8.75|
# +-----------+-------------------+----------------+-------------+

# %%
# Graph the data using matplotlib
#The name df1 stands for dataframe1 for the first .csv file, cities
column_names=["City", "Latitude", "Longitude"]
# df1 = pd.read_csv(cities, header=None, names=column_names)

#The name df2 stands for dataframe2 for the second .csv file, distances
# column_names2=["Source", "Destination", "Distance"]
# df2 = pd.read_csv(distances, header=None, names=column_names2)

# Display a 2D graph of the given data.

#Combine the longitude and latitude to form coordinates
weather_data["Coordinates"] = list(zip(weather_data.Longitude, weather_data.Latitude))

#Change coordinates from tuples to shapely point objects
weather_data["Coordinates"] = weather_data["Coordinates"].apply(Point)

#Converting DataFrame to GeoDataFrame
gdf1 = gpd.GeoDataFrame(weather_data, geometry="Coordinates")

#Getting map of Texas
texas = gpd.read_file("http://www2.census.gov/geo/tiger/GENZ2016/shp/cb_2016_us_state_5m.zip")

#gdf1.head()
fig, gax = plt.subplots(figsize=(20,20))

texas.query("NAME == 'Texas'").plot(ax=gax, edgecolor='black',color='white')

gdf1.plot(ax=gax, color='red', alpha = 1)

gax.set_xlabel('Longitude')
gax.set_ylabel('Latitude')
gax.set_title('Texas')

gax.spines['top'].set_visible(False)
gax.spines['right'].set_visible(False)

# Label the cities
for x, y, label in zip(gdf1['Coordinates'].x, gdf1['Coordinates'].y, gdf1['City']):
    gax.annotate(label, xy=(x,y), xytext=(2,2), textcoords='offset points')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 13
#       3 column_names=["City", "Latitude", "Longitude"]
#       4 # df1 = pd.read_csv(cities, header=None, names=column_names)
#       5
#       6 #The name df2 stands for dataframe2 for the second .csv file, distances
#    (...)
#      11
#      12 #Combine the longitude and latitude to form coordinates
# ---> 13 df1["Coordinates"] = list(zip(weather_data.Longitude, weather_data.Latitude))
#      15 #Change coordinates from tuples to shapely point objects
#      16 df1["Coordinates"] = weather_data["Coordinates"].apply(Point)
#
# File ~/my_project_dir/my_project_env/lib/python3.10/site-packages/pyspark/sql/dataframe.py:3127, in DataFrame.__getattr__(self, name)
#    3094 """Returns the :class:`Column` denoted by ``name``.
#    3095
#    3096 .. versionadded:: 1.3.0
#    (...)
#    3124 +---+
#    3125 """
#    3126 if name not in self.columns:
# -> 3127     raise AttributeError(
#    3128         "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    3129     )
#    3130 jc = self._jdf.apply(name)
#    3131 return Column(jc)
#
# AttributeError: 'DataFrame' object has no attribute 'Longitude'

# %%
# https://www.askpython.com/python/examples/weather-forecast-using-python
# https://github.com/chubin/wttr.in

# Function to Generate Report
def generate_report(C):
    url = 'https://wttr.in/{}'.format(C)
    try:
        data = requests.get(url)
        data_text = data.text
    except:
        data_text = "Error Occurred"
    print(data_text)

for city in cities:
    generate_report(city)
# Out:
# Weather report: San Antonio
#
#      \  /       Partly cloudy
#    _ /"".-.     +82(86) °F
#      \_(   ).   ↖ 18 mph
#      /(___(__)  9 mi
#                 0.0 in
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Thu 25 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Overcast       │               Overcast       │    \  /       Partly cloudy  │  _`/"".-.     Thundery outbr…│
# │      .--.     +71(77) °F     │      .--.     +77(78) °F     │  _ /"".-.     +82(84) °F     │   ,\_(   ).   +75(78) °F     │
# │   .-(    ).   ↖ 11-14 mph    │   .-(    ).   ↖ 14-18 mph    │    \_(   ).   ↖ 18-22 mph    │    /(___(__)  ↖ 18-26 mph    │
# │  (___.__)__)  6 mi           │  (___.__)__)  6 mi           │    /(___(__)  9 mi           │     ⚡‘‘⚡‘‘  5 mi           │
# │               0.0 in | 0%    │               0.0 in | 0%    │               0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Fri 26 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy rain ne…│  _`/"".-.     Thundery outbr…│  _`/"".-.     Thundery outbr…│     \   /     Clear          │
# │   ,\_(   ).   +73(77) °F     │   ,\_(   ).   +78(82) °F     │   ,\_(   ).   +80(84) °F     │      .-.      +75(78) °F     │
# │    /(___(__)  ↑ 11-16 mph    │    /(___(__)  ↖ 18-21 mph    │    /(___(__)  ↖ 14-18 mph    │   ― (   ) ―   ↖ 14-22 mph    │
# │      ‘ ‘ ‘ ‘  6 mi           │     ⚡‘‘⚡‘‘  5 mi           │     ⚡‘‘⚡‘‘  5 mi           │      `-’      6 mi           │
# │     ‘ ‘ ‘ ‘   0.0 in | 65%   │     ‘ ‘ ‘ ‘   0.0 in | 100%  │     ‘ ‘ ‘ ‘   0.0 in | 76%   │     /   \     0.0 in | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Sat 27 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy rain ne…│  _`/"".-.     Thundery outbr…│  _`/"".-.     Thundery outbr…│  _`/"".-.     Thundery outbr…│
# │   ,\_(   ).   +73(77) °F     │   ,\_(   ).   +75(78) °F     │   ,\_(   ).   +84(87) °F     │   ,\_(   ).   +75(78) °F     │
# │    /(___(__)  ↖ 14-20 mph    │    /(___(__)  ↖ 16-20 mph    │    /(___(__)  ↖ 19-22 mph    │    /(___(__)  ↖ 19-26 mph    │
# │      ‘ ‘ ‘ ‘  6 mi           │     ⚡‘‘⚡‘‘  5 mi           │     ⚡‘‘⚡‘‘  5 mi           │     ⚡‘‘⚡‘‘  5 mi           │
# │     ‘ ‘ ‘ ‘   0.0 in | 86%   │     ‘ ‘ ‘ ‘   0.0 in | 100%  │     ‘ ‘ ‘ ‘   0.0 in | 85%   │     ‘ ‘ ‘ ‘   0.0 in | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: San Antonio, Bexar County, Texas, United States of America [29.4246002,-98.4951404]
#
# Follow @igor_chubin for wttr.in updates
#
# Weather report: Austin
#
#      \  /       Partly cloudy
#    _ /"".-.     +80(84) °F
#      \_(   ).   ↑ 11 mph
#      /(___(__)  8 mi
#                 0.0 in
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Thu 25 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy rain ne…│  _`/"".-.     Patchy rain ne…│  _`/"".-.     Patchy rain ne…│               Cloudy         │
# │   ,\_(   ).   69 °F          │   ,\_(   ).   +75(78) °F     │   ,\_(   ).   +78(82) °F     │      .--.     +73(77) °F     │
# │    /(___(__)  ↖ 9-13 mph     │    /(___(__)  ↖ 13-16 mph    │    /(___(__)  ↖ 14-19 mph    │   .-(    ).   ↖ 14-22 mph    │
# │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │  (___.__)__)  6 mi           │
# │     ‘ ‘ ‘ ‘   0.0 in | 76%   │     ‘ ‘ ‘ ‘   0.0 in | 63%   │     ‘ ‘ ‘ ‘   0.0 in | 100%  │               0.0 in | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Fri 26 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy rain ne…│     \   /     Sunny          │  _`/"".-.     Patchy light r…│  _`/"".-.     Thundery outbr…│
# │   ,\_(   ).   +71(77) °F     │      .-.      +80(82) °F     │   ,\_(   ).   +78(82) °F     │   ,\_(   ).   +75(78) °F     │
# │    /(___(__)  ↑ 13-19 mph    │   ― (   ) ―   ↑ 16-18 mph    │    /(___(__)  ↑ 14-18 mph    │    /(___(__)  ↖ 13-19 mph    │
# │      ‘ ‘ ‘ ‘  6 mi           │      `-’      6 mi           │     ⚡‘‘⚡‘‘  6 mi           │     ⚡‘‘⚡‘‘  5 mi           │
# │     ‘ ‘ ‘ ‘   0.0 in | 100%  │     /   \     0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 100%  │     ‘ ‘ ‘ ‘   0.0 in | 0%    │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Sat 27 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Overcast       │  _`/"".-.     Thundery outbr…│  _`/"".-.     Thundery outbr…│  _`/"".-.     Thundery outbr…│
# │      .--.     +73(77) °F     │   ,\_(   ).   +77(80) °F     │   ,\_(   ).   +82(87) °F     │   ,\_(   ).   +75(78) °F     │
# │   .-(    ).   ↖ 16-21 mph    │    /(___(__)  ↖ 18-20 mph    │    /(___(__)  ↖ 18-21 mph    │    /(___(__)  ↖ 16-22 mph    │
# │  (___.__)__)  6 mi           │     ⚡‘‘⚡‘‘  5 mi           │     ⚡‘‘⚡‘‘  5 mi           │     ⚡‘‘⚡‘‘  5 mi           │
# │               0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 84%   │     ‘ ‘ ‘ ‘   0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 63%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Austin, Travis County, Texas, United States of America [30.2711286,-97.7436994]
#
# Follow @igor_chubin for wttr.in updates
#
# Weather report: Dallas
#
#                 Overcast
#        .--.     +77(80) °F
#     .-(    ).   ↖ 13 mph
#    (___.__)__)  9 mi
#                 0.0 in
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Thu 25 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly Cloudy  │  _`/"".-.     Patchy rain ne…│  _`/"".-.     Thundery outbr…│  _`/"".-.     Thundery outbr…│
# │  _ /"".-.     69 °F          │   ,\_(   ).   +73(77) °F     │   ,\_(   ).   +77(80) °F     │   ,\_(   ).   +73(78) °F     │
# │    \_(   ).   ↖ 11-14 mph    │    /(___(__)  ↑ 13-15 mph    │    /(___(__)  ↑ 11-16 mph    │    /(___(__)  ↖ 14-23 mph    │
# │    /(___(__)  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │     ⚡‘‘⚡‘‘  5 mi           │     ⚡‘‘⚡‘‘  5 mi           │
# │               0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 100%  │     ‘ ‘ ‘ ‘   0.0 in | 72%   │     ‘ ‘ ‘ ‘   0.0 in | 100%  │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Fri 26 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Thundery outbr…│  _`/"".-.     Thundery outbr…│     \   /     Sunny          │  _`/"".-.     Patchy light r…│
# │   ,\_(   ).   69 °F          │   ,\_(   ).   69 °F          │      .-.      +77(80) °F     │   ,\_(   ).   +73(77) °F     │
# │    /(___(__)  ↑ 14-21 mph    │    /(___(__)  ↑ 15-24 mph    │   ― (   ) ―   ↑ 16-24 mph    │    /(___(__)  ↑ 14-26 mph    │
# │     ⚡‘‘⚡‘‘  5 mi           │     ⚡‘‘⚡‘‘  5 mi           │      `-’      6 mi           │     ⚡‘‘⚡‘‘  6 mi           │
# │     ‘ ‘ ‘ ‘   0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 100%  │     /   \     0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 100%  │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Sat 27 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Thundery outbr…│  _`/"".-.     Patchy rain ne…│  _`/"".-.     Light rain sho…│  _`/"".-.     Thundery outbr…│
# │   ,\_(   ).   +71(77) °F     │   ,\_(   ).   +77(80) °F     │   ,\_(   ).   +80(84) °F     │   ,\_(   ).   +75(78) °F     │
# │    /(___(__)  ↖ 15-22 mph    │    /(___(__)  ↖ 16-22 mph    │    /(___(__)  ↑ 20-29 mph    │    /(___(__)  ↖ 19-30 mph    │
# │     ⚡‘‘⚡‘‘  5 mi           │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │     ⚡‘‘⚡‘‘  5 mi           │
# │     ‘ ‘ ‘ ‘   0.0 in | 71%   │     ‘ ‘ ‘ ‘   0.0 in | 100%  │     ‘ ‘ ‘ ‘   0.0 in | 100%  │     ‘ ‘ ‘ ‘   0.0 in | 74%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Dallas, Dallas County, Texas, United States of America [32.7762719,-96.7968558]
#
# Follow @igor_chubin for wttr.in updates
#
# Weather report: Houston
#
#      \  /       Partly cloudy
#    _ /"".-.     +80(84) °F
#      \_(   ).   ↖ 18 mph
#      /(___(__)  9 mi
#                 0.0 in
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Thu 25 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy rain ne…│  _`/"".-.     Patchy rain ne…│  _`/"".-.     Patchy rain ne…│  _`/"".-.     Patchy rain ne…│
# │   ,\_(   ).   +75(78) °F     │   ,\_(   ).   +78(82) °F     │   ,\_(   ).   +78(82) °F     │   ,\_(   ).   +73(77) °F     │
# │    /(___(__)  ↖ 10-13 mph    │    /(___(__)  ↖ 12-14 mph    │    /(___(__)  ↖ 14-18 mph    │    /(___(__)  ↖ 10-14 mph    │
# │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │
# │     ‘ ‘ ‘ ‘   0.0 in | 65%   │     ‘ ‘ ‘ ‘   0.0 in | 83%   │     ‘ ‘ ‘ ‘   0.0 in | 72%   │     ‘ ‘ ‘ ‘   0.0 in | 72%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Fri 26 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Overcast       │    \  /       Partly Cloudy  │  _`/"".-.     Patchy rain ne…│  _`/"".-.     Patchy rain ne…│
# │      .--.     +75(78) °F     │  _ /"".-.     +80(84) °F     │   ,\_(   ).   +78(82) °F     │   ,\_(   ).   +75(78) °F     │
# │   .-(    ).   ↖ 12-16 mph    │    \_(   ).   ↑ 16-18 mph    │    /(___(__)  ↖ 15-18 mph    │    /(___(__)  ↖ 12-16 mph    │
# │  (___.__)__)  6 mi           │    /(___(__)  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │      ‘ ‘ ‘ ‘  6 mi           │
# │               0.0 in | 0%    │               0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 71%   │     ‘ ‘ ‘ ‘   0.0 in | 60%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Sat 27 Apr ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly Cloudy  │     \   /     Sunny          │  _`/"".-.     Thundery outbr…│  _`/"".-.     Thundery outbr…│
# │  _ /"".-.     +77(80) °F     │      .-.      +84(87) °F     │   ,\_(   ).   +80(84) °F     │   ,\_(   ).   +77(80) °F     │
# │    \_(   ).   ↖ 15-18 mph    │   ― (   ) ―   ↖ 18-21 mph    │    /(___(__)  ↖ 18-21 mph    │    /(___(__)  ↖ 16-21 mph    │
# │    /(___(__)  6 mi           │      `-’      6 mi           │     ⚡‘‘⚡‘‘  5 mi           │     ⚡‘‘⚡‘‘  5 mi           │
# │               0.0 in | 0%    │     /   \     0.0 in | 0%    │     ‘ ‘ ‘ ‘   0.0 in | 79%   │     ‘ ‘ ‘ ‘   0.0 in | 62%   │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Houston, Harris County, Texas, United States of America [29.7589382,-95.3676973]
#
# Follow @igor_chubin for wttr.in updates
